# %%
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
from pyresample import kd_tree, geometry

# %% [markdown]
# np.fromfile(fname, dtype=dt)
# array([((10, 0), 98.25)],
#       dtype=[('time', [('min', '<i4'), ('sec', '<i4')]), ('temp', '<f8')])

# %%
grd_file = r'/Users/gonzalgo/Downloads/greenl_00411_16035_004_160326_ALTTBB_HH_03.hgt.grd'

# %%
glob.glob('/Users/gonzalgo/Downloads/*')
# Out:
# ['/Users/gonzalgo/Downloads/InstallBackupAndSync.dmg',
#  '/Users/gonzalgo/Downloads/QGIS Example.qgz',
#  '/Users/gonzalgo/Downloads/Install Spotify.app',
#  '/Users/gonzalgo/Downloads/PanoplyMacOS-4.10.7.dmg',
#  '/Users/gonzalgo/Downloads/greenl_00411_16035_004_160326_ALTTBB_HH_03.ann',
#  '/Users/gonzalgo/Downloads/glistin.yml',
#  '/Users/gonzalgo/Downloads/greenl_00411_16035_004_160326_ALTTBB_HH_03.hgt.grd']

# %%
x=np.fromfile(grd_file, dtype = '<f4')

# %%
x.shape
# Out:
# (513583532,)

# %%
len(x)/35668
# Out:
# 14399.0

# %%
np.min(x)
# Out:
# -10000.0

# %%
x = np.reshape(x,(35668, 14399))

# %%
plt.imshow(x[::100, ::100], vmin=0, vmax=500);plt.colorbar()

# %%
x_ma = np.where(x > -10000, x, np.nan)

# %%
plt.imshow(x_ma[::100, ::100], vmin=0, vmax=500);plt.colorbar()

# %%
plt.figure(figsize=(10,10));plt.imshow(x_ma[::10, ::10], vmin=0, vmax=500);plt.colorbar()

# %%
plt.figure(figsize=(10,10));plt.imshow(x_ma, vmin=0, vmax=500);plt.colorbar()

# %%
x.shape
# Out:
# (35668, 14399)

# %%
lats = np.linspace(77.6, 76.5, 35669)
lons = np.linspace(-22.9, -21.9, 1440)

# %%
plt.figure(figsize=(10, 10)); plt.pcolormesh(lons[::100], lats[::100], x_ma[::100, ::100])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-2206a17e8ad1> in <module>
# ----> 1 plt.figure(figsize=(10, 10)); plt.pcolormesh(lons[::100], lats[::100], x_ma[::100, ::100])
#
# /anaconda3/envs/glistin/lib/python3.6/site-packages/matplotlib/pyplot.py in pcolormesh(alpha, norm, cmap, vmin, vmax, shading, antialiased, data, *args, **kwargs)
#    2749         *args, alpha=alpha, norm=norm, cmap=cmap, vmin=vmin,
#    2750         vmax=vmax, shading=shading, antialiased=antialiased,
# -> 2751         **({"data": data} if data is not None else {}), **kwargs)
#    2752     sci(__ret)
#    2753     return __ret
#
# /anaconda3/envs/glistin/lib/python3.6/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1587     def inner(ax, *args, data=None, **kwargs):
#    1588         if data is None:
# -> 1589             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1590
#    1591         bound = new_sig.bind(ax, *args, **kwargs)
#
# /anaconda3/envs/glistin/lib/python3.6/site-packages/matplotlib/axes/_axes.py in pcolormesh(self, alpha, norm, cmap, vmin, vmax, shading, antialiased, *args, **kwargs)
#    6144         allmatch = (shading == 'gouraud')
#    6145
# -> 6146         X, Y, C = self._pcolorargs('pcolormesh', *args, allmatch=allmatch)
#    6147         Ny, Nx = X.shape
#    6148         X = X.ravel()
#
# /anaconda3/envs/glistin/lib/python3.6/site-packages/matplotlib/axes/_axes.py in _pcolorargs(funcname, allmatch, *args)
#    5739                 raise TypeError('Dimensions of C %s are incompatible with'
#    5740                                 ' X (%d) and/or Y (%d); see help(%s)' % (
# -> 5741                                     C.shape, Nx, Ny, funcname))
#    5742             C = C[:Ny - 1, :Nx - 1]
#    5743         C = cbook.safe_masked_invalid(C)
#
# TypeError: Dimensions of C (357, 144) are incompatible with X (15) and/or Y (357); see help(pcolormesh)

# %%
swath_def = geometry.SwathDefinition(lons=35668, lats=14399)

# %%
# Area of new common grid in different coordinate system
area_id = 'ease'
description = 'ease grid north'
proj_id = 'greenl_00411_16'
proj_string = 'EPSG:6931'
width = 14399
height = 35668
area_extent = (-2286563, -2336644, -544973, -880249)
area_def = geometry.AreaDefinition(area_id, description, \
                                    proj_id, proj_string, width, 
                                    height, area_extent)\

# %%
result = kd_tree.resample_nearest(swath_def, x, area_def, \
                                  radius_of_influence=34000, fill_value=np.nan)
