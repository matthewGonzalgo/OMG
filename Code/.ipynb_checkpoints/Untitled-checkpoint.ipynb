# %%
import numpy as np
import os
import glob
import matplotlib.pyplot as plt
import pyresample as pyr
from pyresample import kd_tree, geometry

# %%
grd_file = r'/Users/fhgraham/desktop/GRDData/greenl_00411_16035_004_160326_ALTTBB_HH_03.hgt.grd'

# %%
glob.glob('/Users/fhgraham/desktop/GRDData/*')
# Out:
# ['/Users/fhgraham/desktop/GRDData/greenl_00411_16035_004_160326_ALTTBB_HH_03.ann',
#  '/Users/fhgraham/desktop/GRDData/greenl_00411_16035_004_160326_ALTTBB_HH_03.hgt.grd']

# %%
x=np.fromfile(grd_file, dtype = '<f4')

# %%
x.shape
# Out:
# (513583532,)

# %%
len(x)/35668
# Out:
# 14399.0

# %%
x=np.reshape(x,(35668, 14399))

# %%
plt.imshow(x[::100,::100], vmin = 0, vmax= 500);plt.colorbar()

# %%
x_ma = np.where(x > -10000, x , np.nan)

# %%
plt.figure(figsize=(10,10));plt.imshow(x_ma[::5,::5], vmin = 0, vmax= 500);plt.colorbar()

# %%
lats = np.linspace(77.49109, 76.50031, 35669)
lons = np.linspace(-22.74941,-21.94946, 14400)

# %%
plt.figure(figsize=(10,10));plt.pcolormesh(lons[::100],lats[::100],x_ma[::100,::100]);plt.grid();plt.colorbar()

# %%
x_ma[::100,:100].shape
lons.shape
# Out:
# (14400,)

# %%
area_id = 'WGS 84'
description = "lat lon"
proj_id = 'WGS 84'
proj_string = 'EPSG:4326'
width = 14400
height = 35669
area_extent = (-22.9, 76.5, -21.9, 77.5)
area_def_original = geometry.AreaDefition
